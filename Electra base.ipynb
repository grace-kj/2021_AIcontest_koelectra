# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/국립국어원_Electra/'
# Out:
# /content/drive/MyDrive/Colab Notebooks/국립국어원_Electra

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r requirements.txt

# %%
# !chmod 755 run_BoolQ.sh
# !./run_BoolQ.sh
# Out:
# Traceback (most recent call last):
#   File "run_seq_cls.py", line 9, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-282bf25b0c5d> in <module>()
#       1 get_ipython().system('chmod 755 run_BoolQ.sh')
# ----> 2 get_ipython().system('./run_BoolQ.sh')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# ...

# %%
# !python log.py --task BoolQ
# Out:
# (8, 2e-05, 0.8371428571428572, 2300)
# (8, 2e-05, 0.8257142857142857, 1500)
# (4, 1e-05, 0.8257142857142857, 2500)
# (4, 1e-05, 0.8157142857142857, 5400)
# (8, 2e-05, 0.8157142857142857, 800)

# %%
(8, 2e-05, 0.8257142857142857, 1500)
(4, 1e-05, 0.8257142857142857, 2500)
(4, 1e-05, 0.8157142857142857, 5400)
(8, 2e-05, 0.8157142857142857, 800)
